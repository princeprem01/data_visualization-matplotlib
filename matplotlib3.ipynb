# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb

# %%
df= pd.read_csv(r"C:\Users\Lucky Prem\Downloads\organizations-100\heart-disease.csv")
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df.age.plot.hist(bins=40); #showing normal distribution

# %%
df[df.age>30].count() #removing outliers
# Out:
# age         302
# sex         302
# cp          302
# trestbps    302
# chol        302
# fbs         302
# restecg     302
# thalach     302
# exang       302
# oldpeak     302
# slope       302
# ca          302
# thal        302
# target      302
# dtype: int64

# %%
df=df[df.age>30]
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
#df.plot.hist(subplots=True, figsize=(5,20));    #when subplots=True, all have common x-axis values/range
df[['trestbps','chol','thalach']].plot.hist(subplots=True, figsize=(5,10));

# %%
df[['trestbps','chol','thalach']].plot.hist(figsize=(5,10));

# %%
#use OO method over pyplot method#
#1 Pyplot method

df.plot(x='age', y='chol', kind='scatter', c='target')
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
df.plot(x='age', y='chol', kind='scatter', c='target', figsize=(8,5), colormap='BrBG');

# %%
#2 OO method
fig, ax= plt.subplots(figsize=(8,5))
ax.scatter(df['age'],df['chol'],c=df['target'], cmap='BrBG');
ax.set(xlabel='age', ylabel='chol');

# %%
# OO method mixed with Pyplot method
fig, ax=plt.subplots(figsize=(8,5)) #df.plot(df['age'], df['chol'] KeyError: "None of [Index([63, 37, 41, 56, 57, 57, 56, 44, 52, 57,\n       ...\n       67, 44, 63, 63, 59, 57, 45, 68, 57, 57],\n      dtype='int64', length=303)] are in the [columns]". df is already in the begaining so just provide column names and not df. or again df[''] 
df.plot(x='age', y='chol', kind='scatter', c='target', cmap='BrBG', ax=ax);

# %%
fig, ax=plt.subplots(nrows=1, ncols=2, figsize=(12,6))
a1=df.plot(x='age', y='chol', kind='scatter', c='target', cmap='BrBG', ax=ax[0]);
df.plot(y='age', kind='hist', bins=40, ax=ax[1]);
a1.legend(*a1.collections[0].legend_elements(), title='Legend') #The ax.legend() call does not automatically generate a legend for a scatter plot based on the c (color) argument because matplotlib doesn't inherently know how to interpret the c values as categories for the legend. The legend needs to be explicitly told what each color represents.

# %%
#2 OO method:Lets do some more customizations

fig, ax= plt.subplots(figsize=(8,5))
sc=ax.scatter((df['age']),df['chol'],c=df['target'], cmap='BrBG');
ax.set(xlabel='age', ylabel='chol');
ax.legend(*sc.legend_elements(), title="Legends"); #The ax.legend() call does not automatically generate a legend for a scatter plot based on the c (color) argument because matplotlib doesn't inherently know how to interpret the c values as categories for the legend. The legend needs to be explicitly told what each color represents.

# %%
fig, ax= plt.subplots(figsize=(8,5))
axes=ax.scatter((df['age']),df['chol'],c=df['target'], cmap='BrBG');
axes.legend_elements()
# Out:
# ([<matplotlib.lines.Line2D at 0x239db2063d0>,
# ...
#  ['$\\mathdefault{0}$', '$\\mathdefault{1}$'])

# %%
fig, ax= plt.subplots(figsize=(8,5))
sc=ax.scatter((df['age']),df['chol'],c=df['target'], cmap='BrBG');
ax.set(xlabel='age', ylabel='chol')
ax.axhline(df.chol.mean(), linestyle='--', c='black' )
ax.legend(*sc.legend_elements(), title="Legends");
#added a horizontal line

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
fig, ax= plt.subplots(ncols=1,nrows=2,figsize=(9,9), sharex=True)

a1=ax[0].scatter(df['age'],df['chol'], c=df['target'], cmap='BrBG') #df.plot(df['age'], df['chol'] KeyError: "None of [Index([63, 37, 41, 56, 57, 57, 56, 44, 52, 57,\n       ...\n       67, 44, 63, 63, 59, 57, 45, 68, 57, 57],\n      dtype='int64', length=303)] are in the [columns]". df is already in the begaining so just provide column names and not df. or again df[''] 
ax[0].set(title='Age vs Chol')
ax[0].axhline(df['chol'].mean(), linestyle='--')
ax[0].legend(*a1.legend_elements(),title='Legend1') #using pandas' DataFrame.plot with kind='scatter', adding a legend for the c (color) argument requires a bit of manual work because pandas does not automatically generate legends

a2=ax[1].scatter(df['age'],df['thalach'], c=df['target'], cmap='Accent_r');
ax[1].set(title='Age vs Thalach')
ax[1].axhline(df.thalach.median(), linestyle='--');
ax[1].legend(*a2.legend_elements(), title='Legend2')

fig.suptitle('Scatter Graphs', fontsize=14, fontweight='bold'); #complete figure's super title

# %% [markdown]
# ## Customize further with different styles

# %%
plt.style.use('default')

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('ggplot')

# %%
#create some data
np.random.seed(1)
xx=np.random.randn(10,5)
#xx

# %%
tb=pd.DataFrame(data=xx, columns=["A","B","C","D",'F'])
tb
# Out:
#           A         B         C         D         F
# 0  1.624345 -0.611756 -0.528172 -1.072969  0.865408
# 1 -2.301539  1.744812 -0.761207  0.319039 -0.249370
# 2  1.462108 -2.060141 -0.322417 -0.384054  1.133769
# 3 -1.099891 -0.172428 -0.877858  0.042214  0.582815
# 4 -1.100619  1.144724  0.901591  0.502494  0.900856
# 5 -0.683728 -0.122890 -0.935769 -0.267888  0.530355
# 6 -0.691661 -0.396754 -0.687173 -0.845206 -0.671246
# 7 -0.012665 -1.117310  0.234416  1.659802  0.742044
# 8 -0.191836 -0.887629 -0.747158  1.692455  0.050808
# 9 -0.636996  0.190915  2.100255  0.120159  0.617203

# %%
tb['A'].plot()
# Out:
# <Axes: >

# %%
plt.style.use('classic')

# %%
tb['A'].plot.bar();

# %%
plt.style.use('seaborn-v0_8-whitegrid')

a1=tb.plot.bar(figsize=(14,12));
a1.set(xlabel='A Column'); #automatically generate legend 
#ax.legend().set_visible(True);

# %%
tb['G']=np.random.randint(2,size=len(tb))
tb
# Out:
#           A         B         C         D         F  G
# 0  1.624345 -0.611756 -0.528172 -1.072969  0.865408  1
# 1 -2.301539  1.744812 -0.761207  0.319039 -0.249370  1
# 2  1.462108 -2.060141 -0.322417 -0.384054  1.133769  0
# 3 -1.099891 -0.172428 -0.877858  0.042214  0.582815  1
# 4 -1.100619  1.144724  0.901591  0.502494  0.900856  0
# 5 -0.683728 -0.122890 -0.935769 -0.267888  0.530355  1
# 6 -0.691661 -0.396754 -0.687173 -0.845206 -0.671246  0
# 7 -0.012665 -1.117310  0.234416  1.659802  0.742044  0
# 8 -0.191836 -0.887629 -0.747158  1.692455  0.050808  0
# 9 -0.636996  0.190915  2.100255  0.120159  0.617203  1

# %%
plt.style.use('seaborn-v0_8')

a1=tb.plot.scatter(x='A', y='B',c='G')
a1.set(xlabel='A Values', ylabel='B Values' ,title='Scatter Plot', ylim=(-3,3))
a1.legend(*a1.collections[0].legend_elements(), title='Legends');
